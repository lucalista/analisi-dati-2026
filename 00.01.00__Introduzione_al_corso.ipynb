# %% [markdown]
# ## Introduzione al corso di:
# # Analisi Statistica dei Dati Sperimentali
# ## Corso di Laurea triennale in Fisica
# ### <a href="http://people.na.infn.it/~lista/">Prof. Luca Lista</a>
#
# Il corso si propone di fornire **strumenti concettuali e pratici** per analizzare i dati sperimentali con **tecnologie e metodi moderni**.
#
# Gli aspetti teorici saranno introdotti insieme ad applicazioni a dati reali o simulati.
#
# Tutti i risultati e gli esempi forniti durante il corso saranno replicabili dagli studenti, e potranno essere riutilizzati per future applicazioni, come i prossimi esami di laboratorio o, infine, la tesi di Laurea.
#
# L'analisi dei dati è uno strumento principalmente usato per **attività sperimentali** di laboratorio, ma l'analisi di dati simulati e il confronto dei dati sperimentali con i modelli teorici sono di grande e crescente importanza anche per la **fisica teorica**.

# %% [markdown]
# ## Come si svolgono le lezioni
#
# Le lezioni hanno una parte di presentazione frontale con *notebook* jupyter, come questa pagina, che potranno contenere formule, grafici e codice,
# e una parte interattiva dove gli studenti realizzeranno mini-progetti mettendo in pratica i concetti presentati.

# %% [markdown]
# ## Come si svolge l'esame
#
# L'esame ha due parti:
# 1. un progetto a scelta degli studenti, da realizzare in gruppo o singolarmente. Il numero ottimale è due persone. Il progetto prevede una proposta che va fatta prima di inziare il progetto, possibilmente un incontro intermedio, e poi la discussione durante l'esame.
# 1. Una seconda parte dell'esame orale sarà fatta da domande sulla teoria trattata durante le lezioni.

# %% [markdown]
# ## Argomenti del corso
#
# Gli argomenti del corso proposti inizialmente nel syllabus potranno cambiare leggermente durante lo svolgimento del corso in base agli interessi degli studenti, e saranno di conseguenza aggiornati i contenuti di queste pagine contenute nel repository [GitHub](https://github.com/lucalista/analisi-dati-2025).
#
# Le applicazioni pratiche seguiranno il progredire, durante il corso, del livello di apprendimento e padronanza degli strumenti teorici e applicativi. In base a questo, saranno stabiliti i ritmi delle lezioni, piuttosto che rispetto ad una scaletta temporale prestabilita.

# %% [markdown]
# ## Libro di testo
#
# Il libro di testo è:
#   * [Statistical Methods for Data Analysis With Applications in Particle Physics](https://link.springer.com/book/10.1007/978-3-031-19934-9)
#
# <img src="img/libro-stat-meth.jpg" width=300>
#
# e può essere scaricato gratuitamente dal sito della Springer per gli studenti della Federico II collegandosi con le credenziali UniNa.

# %% [markdown]
# # Teams
#
# Il link a team è [questo](https://teams.microsoft.com/l/team/19%3ADpgduZFP9a6jtyUTqVVKsjzyZWeyxGirUWKnJrzh5841%40thread.tacv2/conversations?groupId=c85f1c7e-7b66-4f94-a27d-00e1f8966c5e&tenantId=2fcfe26a-bb62-46b0-b1e3-28f9da0c45fd).

# %% [markdown]
# ## 1. Probabilità
#
# Verrà introdotto il concetto di probabilità con diversi approcci, focalizzando l'attenzione sulle applicazioni scientifiche. La teoria della probabilità trova applicazione in due ambiti principali:
#
# * **fenomeni casuali** nella forma di esperimenti che possono essere replicati mantenendo le stesse condizioni, ma dai quali si potrà ottenere, ogni volta che l'esperimento viene ripetuto, un risultato diverso e non prevedibile;
# * **ipotesi o fenomeni non noti o parzialmente noti**, la cui conoscenza potrà migliorare in base alle osservazioni di evidenze sperimentali. Quando una ipotesi acquisisce una credibilità molto grande rispetto alle altre ipotesi alternative, avremo una sua conferma, altrimenti una smentita. In questo senso, la teoria della probabilità è strettamente connessa con il **metodo scientifico** che prova teorie e principi sulla base di evidenze sperimentali.

# %% [markdown]
# ## 2. Numeri casuali
#
# Impareremo a generare con algoritmi sequenze di numeri (pseudo)casuali che seguono distribuzioni volute. Se quenze di numeri casuali saranno usate come laboratorio per avere esperimenti simulati, generati con il computer. Questo ci fornirà campioni di dati complementari ai dati sperimentali di laboratorio, che si potranno analizzare con gli stessi metodi dei dati simulati, e i risultati si potranno mettere a confronto.
#
# Generare numeri casuali o pseudocasuali permette di realizzare esperimenti simulati complementari a quelle di laboratorio.
#
# Per fare questo, introdurremo i **generatori di numeri pseudocasuali** e le tecniche che prendono in generale il nome di metodi **Monte Carlo**.

# %% [markdown]
# ## 3. Approcci Bayesiano e frequentista alla probabilità
#
# Avendo a disposizione generatori di numeri casuali, che ci forniscono un ambiente di laboratorio artificiale, partiremo dalla definzione di **probabilità classica** per poi introdurre due approcci complementari alla probabilità:
# * l'approccio **Bayesiano**, o soggettivo
# * l'approccio **frequentista**
#
# Comprenderemo i campi di applicazione dei due metodi e i limiti di ciascuno.
#
# Le proprietà generali della teoria della probabilità, qualsiasi sia la base concettuale sottostante, possono essere stabilite a partire dall'**approccio assiomatico dovuto a Kolmogorov**, valido per ogni approccio alla probabilità.

# %% [markdown]
# ## 4. Distribuzioni di probabilità
#
# Definito concettualmente il significato di probabilità e l'uso nella pratica della probabilità secondo i diversi approcci, studieremo diverse distribuzioni di probabilità:
# * la distribuzione di Bernulli
# * la distribuzione Binomiale
# * la distribuzione uniforme
# * la distribuzione esponenziale
# * la distribuzione di Poisson
# * la distribuzione di Gauss
# * la distribuzione lognormale
# * la distribuzione Gamma
# * la distribuzione Beta
#
# Comprenderemo meglio le proprietà di queste distribuzioni e quando, in casi concreti, può essere applicata ciascuna di esse.

# %% [markdown]
# ## 5. Stima dei parametri
# In fisica sperimentale è necessario determinare i parametri ignoti di alcune distribuzioni in seguito all'osservazione di risultati sperimentali.
# Questo problema prende il nome di **inferenza**, e si realizza in modo diverso negli approcci bayesiano e frequentista.
#
# Comprenderemo cosa significa **misurare una grandezza fisica** applicando l'inferenza bayesiana o frequentista, e studieremo come assegnare correttamente un **errore** alla misura effettuata, e quindi come trasformare i dati sperimentali in conoscenza scientifica.
#
# Gli intervalli di incertezza assegnate ad una misura hanno significato molto diverso negli approcci bayesiano e frequentista. Si parla, rispettivamente, di **intervalli di credibilità** oppure di **intervalli di confidenza**. Ne comprenderemo il significato ed impareremo come valutarli.

# %% [markdown]
# ## 6. Test di ipotesi
#
# Oltre alla misura di grandezze fisiche, i dati sperimentali consentono di discriminare tra più ipotesi quale siano vere e quali siano false, o, almeno, quali siano più plausibili, oppure descrivano meglio i dati, e quali meno.
#
# Di nuovo, i due approcci bayesiano e frequentista forniscono metodi complementari per effettuare il test di ipotesi.
#
# Diversi algoritmi numerici possono essere usati per discriminare diverse ipotesi, con prestazioni diverse. Alla fine del corso, daremo anche una breve introduzione agli algoritmi di **machine learning** che permettono di ottenere prestazioni vicine ai livelli ottimali previsti dalla teoria.

# %% [markdown]
# ## 7. Scoperte, limiti superiori o inferiori
#
# Se il tempo lo consentirà, faremo accenni a come si può dichiarare una scoperte di un nuovo fenomeno quando è presente un segnale nei dati sperimentali disponibili.
#
# Oppure, in assenza di un segnale che evidenzi un nuovo venomeno che si vuole cercare, come si possa escluderne la presenza almeno per certi intervalli dei valori dei parametri presenti nei modelli ipotizzati. Ad esempio, si può escludere l'esistenza di una particella fino ad un certo valore della sua massa.
